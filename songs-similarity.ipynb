# %% [markdown]
# Annoy offical repository can be found here: https://github.com/spotify/annoy

# %%
import pandas as pd

from annoy import AnnoyIndex

# %% [markdown]
# ## Loading data

# %%
tracks_df = pd.read_csv("./data/tracks_mod.csv")

# %%
tracks_df.shape
# Out:
# (586672, 20)

# %%
tracks_df.dtypes
# Out:
# id                   object
# name                 object
# popularity          float64
# duration_ms           int64
# explicit              int64
# artists              object
# id_artists           object
# release_date         object
# danceability        float64
# energy              float64
# key                 float64
# loudness            float64
# mode                float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature      float64
# dtype: object

# %%
tracks_df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve         6.0
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista         0.0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado         0.0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado         NaN
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening         0.0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645   0.445  0.0   -13.338   1.0       0.4510
# 1   1922-06-01         0.695   0.263  0.0   -22.136   1.0       0.9570
# 2   1922-03-21         0.434   0.177  1.0   -21.180   1.0       0.0512
# 3   1922-03-21         0.321     NaN  7.0   -27.961   1.0       0.0504
# 4         1922         0.402   0.158  3.0   -16.900   0.0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851             3.0
# 1         0.797            0.0000     0.148    0.655  102.009             1.0
# 2         0.994            0.0218     0.212    0.457  130.418             5.0
# 3         0.995            0.9180     0.104    0.397  169.980             3.0
# 4         0.989            0.1300     0.311    0.196  103.220             4.0

# %% [markdown]
# ## Cleaning the data

# %%
tracks_df.dropna(inplace=True)

# %%
tracks_df.shape
# Out:
# (348066, 20)

# %%
print(f"Lost data: {round(1 - tracks_df.shape[0] / 586672, 2)}%")
# Out:
# Lost data: 0.41%

# %% [markdown]
# ### Building the similarity model

# %%
features = ["explicit", "danceability", "energy", "loudness", "speechiness", "liveness", "valence"]
len_features = len(features)

# %%
annoy = AnnoyIndex(len_features, "euclidean")

# %%
for i in tracks_df.index:
    v = tracks_df.loc[i][features].values
    annoy.add_item(i, v)

# %%
annoy.build(1000, n_jobs=-1)
# Out:
# True

# %%
annoy.save("spotify.ann")
# Out:
# True

# %% [markdown]
# ## Getting similar songs

# %%
annoy_loaded = AnnoyIndex(len_features, "euclidean")

# %%
annoy_loaded.load("spotify.ann")
# Out:
# True

# %%
maluma_tracks_df = tracks_df.loc[tracks_df["artists"].str.contains("Maluma")]
maluma_tracks_df["release_date"] = pd.to_datetime(maluma_tracks_df["release_date"])
maluma_tracks_df.sort_values(by=["release_date"], ascending=False).head(1)
# Out:
# /var/folders/dt/2cpm13y17x3982ph7xkhzc_9q89kth/T/ipykernel_88855/2329764219.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   maluma_tracks_df["release_date"] = pd.to_datetime(maluma_tracks_df["release_date"])
#                             id    name  popularity  duration_ms  explicit  \
# 353004  6cDE7xhQZBSHNWB5RX0U9l  Créeme         0.0       214293         0
#
#                       artists  \
# 353004  ['KAROL G', 'Maluma']
#
#                                                id_artists release_date  \
# 353004  ['790FomKkXshlbRYZFtlgla', '1r4hJ1h58CWwUQe3Mx...   2021-04-14
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 353004         0.714   0.874  6.0    -3.576   1.0       0.0549         0.128
#
#         instrumentalness  liveness  valence   tempo  time_signature
# 353004          0.000146     0.105    0.648  96.998             4.0

# %%
neighbors = annoy_loaded.get_nns_by_item(353004, 10)

# %%
tracks_df.loc[neighbors]
# Out:
#                             id               name  popularity  duration_ms  \
# 352972  2Gv3HJSezY4Tln815S7UZH             Créeme         0.0       214293
# 353004  6cDE7xhQZBSHNWB5RX0U9l             Créeme         0.0       214293
# 468734  2ZehPPTmn6QxlI1KedHo51             Créeme         2.0       214293
# 158545  4EKZsrsCKyqr64FBHLc0DU             Créeme        64.0       214293
# 90874   0yyZN5ASdrYu0XYWFzfxUu             3 A.M.        70.0       183573
# 273912  2wuUYbSO8DuvDkxadXVxk4                  酸        12.0       212787
# 578570  1wtSEG4Lxa3h9Sza10BoER  Rendez-Vous i Rio        22.0       195973
# 470422  35jzZ9P5F81sO2VGDxz3OH     Who Needs Love        44.0       211533
# 155157  4haBiYrYQ7AbvQxlt1QahV              Fuera        52.0       217480
# 241467  5yttPxcfowfL4TUYKDqdJe              Sally        35.0       227267
#
#         explicit                                            artists  \
# 352972         0                              ['KAROL G', 'Maluma']
# 353004         0                              ['KAROL G', 'Maluma']
# 468734         0                              ['KAROL G', 'Maluma']
# 158545         0                              ['KAROL G', 'Maluma']
# 90874          0                   ['Jesse & Joy', 'Gente De Zona']
# 273912         0                                       ['Leon Lai']
# 578570         0                                ['Lustans Lakejer']
# 470422         0                                     ['Razorlight']
# 155157         0  ['RBD', 'Anahí', 'Dulce María', 'Maite Perroni...
# 241467         0                                         ['Carmel']
#
#                                                id_artists release_date  \
# 352972  ['790FomKkXshlbRYZFtlgla', '1r4hJ1h58CWwUQe3Mx...   2021-04-14
# 353004  ['790FomKkXshlbRYZFtlgla', '1r4hJ1h58CWwUQe3Mx...   2021-04-14
# 468734  ['790FomKkXshlbRYZFtlgla', '1r4hJ1h58CWwUQe3Mx...   2021-04-09
# 158545  ['790FomKkXshlbRYZFtlgla', '1r4hJ1h58CWwUQe3Mx...   2019-05-03
# 90874   ['1mX1TWKpNxDSAH16LgDfiR', '2cy1zPcrFcXAJTP0AP...   2017-08-18
# 273912                         ['0ubIxkefJsoYY8JXc2HJoa']   1999-05-26
# 578570                         ['3oB3e3MPyQBX5NttDmNUNN']      1981-02
# 470422                         ['450iujbtN6XgiA9pv6fVZz']   2006-01-01
# 155157  ['7cjh6y0V9SsyCrWSXTzwOs', '0TeVa4xdLB8vdzjsvK...   2005-01-01
# 241467                         ['3uDjQUKw2WHSYtZcz2xjDo']   1984-01-01
#
#         danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 352972         0.714   0.874   6.0    -3.576   1.0       0.0549        0.1280
# 353004         0.714   0.874   6.0    -3.576   1.0       0.0549        0.1280
# 468734         0.714   0.874   6.0    -3.576   1.0       0.0549        0.1280
# 158545         0.715   0.874   6.0    -3.576   1.0       0.0548        0.1260
# 90874          0.702   0.840   0.0    -3.547   1.0       0.0879        0.0112
# 273912         0.683   0.881   0.0    -3.601   1.0       0.0348        0.0031
# 578570         0.670   0.898   4.0    -3.557   0.0       0.0317        0.0402
# 470422         0.764   0.887   2.0    -3.605   1.0       0.0308        0.2530
# 155157         0.718   0.866  11.0    -3.590   0.0       0.0417        0.2000
# 241467         0.689   0.883   0.0    -3.643   1.0       0.0367        0.0191
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 352972          0.000146    0.1050    0.648   96.998             4.0
# 353004          0.000146    0.1050    0.648   96.998             4.0
# 468734          0.000146    0.1050    0.648   96.998             4.0
# 158545          0.000162    0.1050    0.652   96.995             4.0
# 90874           0.000000    0.1190    0.624  101.990             4.0
# 273912          0.037600    0.0740    0.611   94.012             4.0
# 578570          0.000052    0.0779    0.630  144.019             4.0
# 470422          0.000000    0.0926    0.676  113.063             4.0
# 155157          0.000000    0.0880    0.717  100.042             4.0
# 241467          0.044200    0.1180    0.640  135.884             4.0
